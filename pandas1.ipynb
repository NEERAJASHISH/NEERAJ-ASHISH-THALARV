# %%
import pandas as pd
df = pd.read_csv("weather.csv")
print(df)
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df = pd.read_csv("weather2.csv")
print(df)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.shape # nine rows and four coloums
# Out:
# (9, 4)

# %%
# in the tuple form
(rows,coloums) = (df.shape)
coloums
# Out:
# 4

# %%
rows
# Out:
# 9

# %%
# head
df.head()
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83

# %%
df.head(1)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56

# %%
df.head(2)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [date, city, temperature, humidity]
# Index: []

# %%
df.head(3)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60

# %%
df.head(5)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83

# %%
#tail function
df.tail()
# Out:
#        date     city  temperature  humidity
# 4  5/2/2017   mumbai           78        83
# 5  5/3/2017   mumbai           82        85
# 6  5/1/2017  beijing           80        26
# 7  5/2/2017  beijing           77        30
# 8  5/3/2017  beijing           79        35

# %%
df.tail(9)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.tail(1)
# Out:
#        date     city  temperature  humidity
# 8  5/3/2017  beijing           79        35

# %%
df.tail(0)
# Out:
# Empty DataFrame
# Columns: [date, city, temperature, humidity]
# Index: []

# %%
df.tail(2)
# Out:
#        date     city  temperature  humidity
# 7  5/2/2017  beijing           77        30
# 8  5/3/2017  beijing           79        35

# %%
df.tail(3)
# Out:
#        date     city  temperature  humidity
# 6  5/1/2017  beijing           80        26
# 7  5/2/2017  beijing           77        30
# 8  5/3/2017  beijing           79        35

# %%
df.tail() # this will print the last five rows
# Out:
#        date     city  temperature  humidity
# 4  5/2/2017   mumbai           78        83
# 5  5/3/2017   mumbai           82        85
# 6  5/1/2017  beijing           80        26
# 7  5/2/2017  beijing           77        30
# 8  5/3/2017  beijing           79        35

# %%
df.tail(3)
# Out:
#        date     city  temperature  humidity
# 6  5/1/2017  beijing           80        26
# 7  5/2/2017  beijing           77        30
# 8  5/3/2017  beijing           79        35

# %%
df.tail(5)
# Out:
#        date     city  temperature  humidity
# 4  5/2/2017   mumbai           78        83
# 5  5/3/2017   mumbai           82        85
# 6  5/1/2017  beijing           80        26
# 7  5/2/2017  beijing           77        30
# 8  5/3/2017  beijing           79        35

# %%
df.tail(9) # it prints all the data
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.head() # this will print first five rows
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [date, city, temperature, humidity]
# Index: []

# %%
df.head(1)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56

# %% [markdown]
# # slicing in pandas

# %%
df = pd.read_csv("weather2.csv")
print(df)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df[3:]
# Out:
#        date     city  temperature  humidity
# 3  5/1/2017   mumbai           75        80
# 4  5/2/2017   mumbai           78        83
# 5  5/3/2017   mumbai           82        85
# 6  5/1/2017  beijing           80        26
# 7  5/2/2017  beijing           77        30
# 8  5/3/2017  beijing           79        35

# %%
df[3:7]
# Out:
#        date     city  temperature  humidity
# 3  5/1/2017   mumbai           75        80
# 4  5/2/2017   mumbai           78        83
# 5  5/3/2017   mumbai           82        85
# 6  5/1/2017  beijing           80        26

# %%
df[:9]
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df[:8]
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30

# %%
df = pd.read_csv("weather2.csv")
print(df)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.columns
# Out:
# Index(['date', 'city', 'temperature', 'humidity'], dtype='object')

# %%
df.loc[[4]]# we can use this method to print the rows
# Out:
#        date    city  temperature  humidity
# 4  5/2/2017  mumbai           78        83

# %%
df[1:2]
# Out:
#        date      city  temperature  humidity
# 1  5/2/2017  new york           66        58

# %%
df.head(9)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df["city"]
# Out:
# 0    new york
# 1    new york
# 2    new york
# 3      mumbai
# 4      mumbai
# 5      mumbai
# 6     beijing
# 7     beijing
# 8     beijing
# Name: city, dtype: object

# %%
df["temperature"]
# Out:
# 0    65
# 1    66
# 2    68
# 3    75
# 4    78
# 5    82
# 6    80
# 7    77
# 8    79
# Name: temperature, dtype: int64

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df[["date","city","temperature"]]
# Out:
#        date      city  temperature
# 0  5/1/2017  new york           65
# 1  5/2/2017  new york           66
# 2  5/3/2017  new york           68
# 3  5/1/2017    mumbai           75
# 4  5/2/2017    mumbai           78
# 5  5/3/2017    mumbai           82
# 6  5/1/2017   beijing           80
# 7  5/2/2017   beijing           77
# 8  5/3/2017   beijing           79

# %%
df["temperature"].max()
# Out:
# 82

# %%
df["temperature"].min()
# Out:
# 65

# %%
df["temperature"].mean()
# Out:
# 74.44444444444444

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
#to print the stasticall data
df.describe()
# Out:
#        temperature   humidity
# count     9.000000   9.000000
# mean     74.444444  57.000000
# std       6.424778  22.841848
# min      65.000000  26.000000
# 25%      68.000000  35.000000
# 50%      77.000000  58.000000
# 75%      79.000000  80.000000
# max      82.000000  85.000000

# %%
df[df.temperature>=32]
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df[df.humidity>=45]
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85

# %%
df[["temperature","humidity"]]
# Out:
#    temperature  humidity
# 0           65        56
# 1           66        58
# 2           68        60
# 3           75        80
# 4           78        83
# 5           82        85
# 6           80        26
# 7           77        30
# 8           79        35

# %%
df[df.temperature==df.temperature.max()]
# Out:
#        date    city  temperature  humidity
# 5  5/3/2017  mumbai           82        85

# %%
df["temperature"].max()
# Out:
# 82

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
# we want to get the line of the maximum temparature
df[df.temperature==df.temperature.max()]
# Out:
#        date    city  temperature  humidity
# 5  5/3/2017  mumbai           82        85

# %%
df[df.temperature==df.temperature.min()]
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56

# %%
#if we get the space in between the words
df[df.humidity==df["humidity"].max()]
# Out:
#        date    city  temperature  humidity
# 5  5/3/2017  mumbai           82        85

# %%
df[df.humidity==df["humidity"].min()]
# Out:
#        date     city  temperature  humidity
# 6  5/1/2017  beijing           80        26

# %%
df[["date","temperature"]]
# Out:
#        date  temperature
# 0  5/1/2017           65
# 1  5/2/2017           66
# 2  5/3/2017           68
# 3  5/1/2017           75
# 4  5/2/2017           78
# 5  5/3/2017           82
# 6  5/1/2017           80
# 7  5/2/2017           77
# 8  5/3/2017           79

# %%
df.temperature
# Out:
# 0    65
# 1    66
# 2    68
# 3    75
# 4    78
# 5    82
# 6    80
# 7    77
# 8    79
# Name: temperature, dtype: int64

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df[["date","humidity"]] [df.temperature==df["temperature"].max()]
# Out:
#        date  humidity
# 5  5/3/2017        85

# %%
df[["date","humidity"]][df.humidity==df["humidity"].max()]
# Out:
#        date  humidity
# 5  5/3/2017        85

# %%
df[0:]
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.loc[[4]]
# Out:
#        date    city  temperature  humidity
# 4  5/2/2017  mumbai           78        83

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
import pandas as pd
df = pd.read_csv("weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.set_index("date",inplace = True)
df
# Out:
#               city  temperature  humidity
# date
# 5/1/2017  new york           65        56
# 5/2/2017  new york           66        58
# 5/3/2017  new york           68        60
# 5/1/2017    mumbai           75        80
# 5/2/2017    mumbai           78        83
# 5/3/2017    mumbai           82        85
# 5/1/2017   beijing           80        26
# 5/2/2017   beijing           77        30
# 5/3/2017   beijing           79        35

# %%
df.loc["5/1/2017"]
# Out:
#               city  temperature  humidity
# date
# 5/1/2017  new york           65        56
# 5/1/2017    mumbai           75        80
# 5/1/2017   beijing           80        26

# %%
df.reset_index(inplace=True)
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35
